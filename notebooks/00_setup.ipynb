# %% [markdown]
# # 00 — Установка окружения
# > **v2 | Агент удержания полосы + ПИД-регулятор | ветка: `v2-agent-pid`**
#
# **Время:** ~2 минуты
# Запускай один раз при первом открытии в Colab.

# %%
# Переключаемся на ветку v2 (запусти первым делом!)
# !git -C /content/drive/MyDrive/diploma fetch origin
# !git -C /content/drive/MyDrive/diploma checkout v2-agent-pid
# !git -C /content/drive/MyDrive/diploma pull
# !echo "Текущая ветка:" && git -C /content/drive/MyDrive/diploma branch --show-current

# %%
# Проверка GPU
import torch
print('CUDA:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
else:
    print('⚠ GPU не найден — зайди в Среда выполнения → Сменить среду → GPU (T4)')

# %%
# Установка зависимостей
# !pip install -q torch torchvision numpy pandas opencv-python-headless matplotlib scikit-learn tqdm

# %%
# Монтирование Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Клонирование репозитория (замени YOUR_USERNAME)
import os

GITHUB_USER = 'YOUR_USERNAME'  # <-- вставь свой username
REPO = 'diploma'
DRIVE_PATH = '/content/drive/MyDrive'
REPO_PATH  = f'{DRIVE_PATH}/{REPO}'

if not os.path.exists(REPO_PATH):
    # !git clone https://github.com/{GITHUB_USER}/{REPO}.git {REPO_PATH}
else:
    # !git -C {REPO_PATH} pull

# Переключаемся на ветку v2
# !git -C {REPO_PATH} checkout v2-agent-pid

os.chdir(REPO_PATH)
print('Рабочая директория:', os.getcwd())

# %%
# Создаём нужные папки
import os
for d in ['data', 'models', 'outputs']:
    os.makedirs(d, exist_ok=True)
print('Готово. Положи dataset.zip в data/ и переходи к ноутбуку 01.')
